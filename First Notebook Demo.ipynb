# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 7))
x_data = ['A', 'B', 'C', 'D', 'E']
y_data = [5, 10, 15, 20, 25]
x_pos = np.arange(len(x_data))
plt.bar(x_pos, y_data)
plt.xticks(x_pos, x_data)
plt.ylabel('Value')
plt.title('Simple Bar Chart')
# Out:
# Text(0.5, 1.0, 'Simple Bar Chart')

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:Qazwsx11@localhost:33066/Brew_App

# %%
import numpy as np
import matplotlib.pyplot as plt

y_data = %sql SELECT distance FROM rides WHERE distance > 50000 LIMIT 100
y_data.sort()
x_data = %sql SELECT average_speed FROM rides WHERE average_speed > 5 LIMIT 100
x_data.sort()

plt.ylabel('Distance (m)')
plt.xlabel('Average Speed (m/s)')
plt.title('Average Time Elapsed')
plt.scatter(x_data, y_data)
# Out:
#  * mysql+pymysql://root:***@localhost:33066/Brew_App
# 100 rows affected.
#  * mysql+pymysql://root:***@localhost:33066/Brew_App
# 100 rows affected.
